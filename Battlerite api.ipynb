# %%
import requests
import pandas as pd
import numpy as np
import json
import datetime
import time
import math as m

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 300)
pd.options.mode.chained_assignment = None

# %%
link = "https://api.developer.battlerite.com/shards/global/matches"

header = {
  "Authorization": "YOUR KEY",
  "Accept": "application/vnd.api+json"
}

# %%
def recode_league(x):
    
    if x == 0:
        return 'Bronze'
    elif x == 1:
        return 'Silver'
    elif x == 2:
        return 'Gold'
    elif x == 3:
        return 'Platinum'
    elif x == 4:
        return 'Diamond'
    elif x == 5:
        return 'Champion'
    else:
        return 'Grand Champion'

# %%
jsonString = r'''{"0":"0","1":"Ashka","797347":"Warm Drink","1394478":"Endless Sand","4782473":"{value} Chests","6507749":"Shadow Princess","9310544":"Beverage","10666209":"Corrupted Doom Cuffs","10957124":"Value Pack","11068112":"Duskwood Scepters","13354321":"Lime Candy Floss","13493115":"Default Weapon","15223860":"Fear Me","15327875":"Sweet Victory","16770104":"Demon Prince","16870326":"Gilded Battlehammers","17705848":"{value} Name change","18275843":"Freya","19214707":"Default Weapon","21110109":"Orman Temple - Day","22068053":"Lime Vaccinator","22207801":"Noble Pointy Staff","23447387":"Mystical Presence","23553499":"Bright Vulpin","24061436":"Speared Flyer","24722838":"Over The Shoulder","26695230":"Radiant Blade","28316917":"Tainted Impaler","30138863":"Bewitching Vestment","31028573":"Radiant Railguns","31966843":"Dark Dadao","32484884":"Default Weapon","33488743":"Oak Astral Gauge","36404258":"Iva`s Courteous Gift","36968935":"Pale Moon Raptor","37145589":"Poloma","38985304":"Lovely Boomstick","39373466":"Jumong","39692927":"Light the winter path","40200211":"Default Weapon","40399520":"Lovely Trouble Maker","40484021":"Ulric Legendary Outfit + 3 x Ulric Chests + 7 Day Boost","41347805":"{value} Shen Rao Chests","44962063":"Pearl","47013841":"Crimson Red","47771557":"Dark Conductors","48823348":"Black Chicken Suit","49455352":"Scarestaff","50902220":"Thorn Chest","51025927":"Cimmerian Herald","51235847":"Stormy Cloud","51549563":"Moon Splitter","52194839":"Scissor Blades","52945820":"Jade War Spear","54167053":"Default Weapon","56495260":"Dragon Cannon ","57656642":"Royal Trooper","57863255":"Default Weapon","58975589":"Dragon Garden - Night","60493172":"Default Pose","63272714":"Heavy  Proton Blaster","64832033":"Clap","65687534":"Jade","66707064":"Unyielding Devotion","67937388":"Lethal Power Conductors","68074861":"Demonic Moose","68356694":"Molten Warhound","72511009":"Refreshment","73333547":"Baby Storm Wyvern","74318452":"Ancient Viper Conductors","74405444":"Deadly Power Conductors","76871976":"Wave","78842081":"Topaz Moon Raptor","79241447":"Noble Spear","80671054":"Oldur","80709830":"Varesh","84940058":"Chartreuse ","85198903":"Deadly Claws of Doom","88814956":"Golden Time Bender","93317594":"Dark Guard","95776013":"Dark Void Conductors","97069347":"Wave","97616490":"Blueberry Vaccinator","101490584":"Graceful Knot","104652792":"Forest Green","104846153":"Scepter of Vindication","107051511":"Black Wolf","108049201":"Anticipation","111278910":"Gems of Insight","112156733":"Yellow Craft Project","113849387":"Clap","114
"The winter challenge","269363261":"Legendary Adventure Pack","270330523":"Wave","270804996":"take a bow","271491542":"Dark Oak Staff","272801113":"The Explorer","281264961":"{value} Chests","281932552":"Default Weapon","282981163":"Winter`s Greed","286048171":"Fairy Flame Bow","286819712":"Scorching Crusher","287241196":"Freya","288759042":"Terror of the Inferno","290244354":"Burning Avatar","290832041":"ta-dah","291990013":"Creepy Lurker Below","292037330":"Young Champion","292783037":"Codex Arcanum","293470812":"Commander of the Western skies","294066347":"Heavy Incinerator","294851947":"Night Beast","295297654":"Moon Night","296620368":"Dragon Wand","297269097":"Frost Blades","298730529":"Bow","303336846":"Spooky Furrycorn","303643329":"Shifu {1}Legendary Outfit{-}","303690117":"Default Outfit","304486655":"Default Outfit","306746865":"{value} Chests","306821074":"Relaxing","309059058":"Antique Bladeweaver","309326884":"Wilderness Raptor","309694495":"Pink Armor","311831565":"Arachnid Play","312054715":"Salute","312750650":"Renowned Hero","314492273":"Clap","315349145":"Lotus","316291888":"Dark Tattoos","317870515":"{value} Chest","320305407":"Night Hunter","322089189":"Noble Conductors","323128526":"Resplendent Gryphon","324609098":"Divine Amber Branch","325120423":"Purple Robe","325335630":"Blast off","326227152":"Illustrious Traveler","326644482":"Salute","327729347":"Gauntlet of Valor","328693419":"Bow","329071895":"Salute","329517751":"Tribal Impaler","330604293":"Fists of Eternity","331020842":"Eye of the Depths","331611129":"Rocket Love","332962185":"{value} day Boost","333024768":"Azure Doom Cuffs","335706485":"Clap","336077239":"Cube of Intellect","337527026":"Adamant Hammer","339453534":"Lunar Beast","340397372":"Jade Orb","341040478":"The Mighty White Tiger","344048839":"Lovehound","344581468":"Ancient Slicer","346776573":"Thumbs Up","350668857":"Bow","350782426":"Smiter of Discord","351322947":"Pumpkinrang","351952170":"Default Weapon","352413906":"Alysia + {value} Alysia Chests","352812563":"Forest Rags","353008214":"Stabbotronics 2000","355237393":"Thunder Serpent","358670667":"Redwood Hunter Bow","358699146":"Mint Lollipop","358973016":"Heart","361474716":"Red Carving Rod","362575358":"Salute","363267025":"Gift Of Companionship","364976110":"Navy Blue","366116810":"Palmy Armbands","366554384":"Endless Hourglass","369797039":"Varesh","372132814":"Cursed Pearl","373686590":"Default Weapon","375302156":"Default Weapon","378567026":"Bow","379351688":"Spiritual Sendoff ","380171576":"Dinner Time","380743989":"Rusty Black","381507998":"Dark Sage","381531726":"Mystic Gold Conductors","383823135":"Lucie","386479715":"The Path","387573318":"Antique Gold Conductors","387582987":"Tri-horned Juggernaut","387753561":"Fair Linden Staff","390954791":"Arctic Cloak","391034496":"Rook","393632653":"Bow","393994367":"Golden Serpent Glaive","396712623":"Oak Arbalest","396974130":"Royal Master Spear","401914366":"Unholy Garment","402688460":"Coral Red","402945358":"Misty Woods - Day","403913508":"Commander of the Northern skies","404620171":"{value} Chests","406212490":"{value} Gems","406747700":"{value} Chests","407331517":"Royal Trident Staff","407828710":"Terrifying Lurker Below","407949747":"Lightbringer","408327069":"Default Weapon","408773361":"Pale Birch Staff","409557280":"Staff of the Frozen Star","411083496":"Arcane Corruption","411291139":"Lovely Gift","412509778":"Veteran`s Morning Star","417844643":"Default Outfit","418518110":"Devil`s Touch","422951320":"{value} Shen Rao Chest","424967161":"Antique Loadout","426441717":"Lime Punk","427901977":"Magnificent Moose","429346264":"Legendary Loot Pack","432455449":"Reinforced Maple Hammers","433949691":"Spunky Pink","435339685":"A small friend","439641408":"Levitate","441065986":"Ember Blades","442342370":"Default Outfit","442427224":"The Infernal Bane Within","445144249":"Forest Guard","445208524":"Twinblades of the Matriarch","448689657":"Champion`s Glider","452211619":"Gold Armament","453562139":"Radiant Herald","455860005":"Frosty Boomstick","456494154":"{value} Gems","457792878":"Looming Terror","459443558":"Unbeatable","460328009":"{value} Chest","461188614":"Deep Blue Guard","466865635":"Wave","467463015":"Lucie","469842865":"{value} Chests","472521410":"Raigon Bundle","474031545":"Arboreal Spirit","476128761":"{value} Chests","478056093":"Hero","481126650":"Golden Guardian","482450619":"Red Tattoos ","483821562":"Prayer","484894278":"Black Rags","485535521":"Lime Green","486225385":"Predator`s Trophies","487555523":"Chiroptera","488967835":"The First Incantation","489206968":"Ashen Birch Staff","491317120":"Drowsy Shaman","491815429":"{value} Chests","493133584":"Grey Battle Wolf","494084622":"Wraith Lord","496169438":"Courteous","497559097":"{value} Gems","502745614":"Toxic Toyblaster 2000","504097754":"Blackberry Lollipop","505422132":"{value} Chests","507268595":"Gold Pointy Staff","507740994":"Default Pose","508618802":"Hallow`s Guard","508632258":"A New Mix","513837906":"Deep Sea Lokum Nautilus","514106651":"{value} Zander Chest","517809219":"Deadly Claws of Horror","518479703":"Thumbs Down","520549809":"Hateful Demon Bow","522978378":"Wyrm Hunter","524089564":"Meow Meow","524144198":"Dark War Scepters","524284754":"Darkwood Hunter Bow","526701155":"Fire Red","527106309":"Ultimate Fan Pack","529763499":"Coin Flip","530272402":"Gaming","534076524":"Arch-Warlock","540898692":"Brass Trouble Maker","541435161":"Jade Dragon Blade","543426522":"Poloma","543520739":"Blossom","543768686":"Default Outfit","545261980":"The Painkillers","546284346":"Ready to strike again","547567895":"Pondering","548281660":"Elder Hunter","550061327":"Ruh Kaan","551968116":"Jade Cutlass","553323459":"Deal With It","553889125":"Meriko Summit - Night","554478717":"Scorched Masked Cuffs","555491343":"BATTLERITE {1}Early Access Bundle{-}","555711278":"Zander","556549694":"Default Weapon","557662854":"{value} Zander Chests","557982098":"Freya {1}Legendary Outfit{-}","558075195":"Venom Grimoire","559636978":"Fiery Yellow Armament","559879834":"Scepter of Winter","560336349":"Burnt Beef n Bash","561043051":"Thermal Blaster","562510476":"Clap","564009924":"Mystic Noble Conductors","565666237":"Woodland Linden Staff","566003020":"Default Weapon","566422881":"Bow","568810007":"The Dragon`s Arsenal","570827724":"Default Outfit","575589592":"Forest Warrior","576579135":"Default Weapon","576879792":"Default Outfit","578166028":"Default Weapon","578350207":"Sweet Critter n Club","578443206":"Red Beard","578593962":"Reinforced Arbal
With it","733228773":"Ashka {1}Legendary Outfit{-}","733684582":"Raigon","733953288":"Gauntlet of Zogan the Black","734380444":"Feed Me","736698003":"Festival Mask","737691090":"Dab Of Pride And Accomplishment","739959916":"Explorer","740140367":"Silver Pointy Staff","743340244":"Conductive War Scepters","743694990":"Frostborn ","745826561":"Cube of Wisdom","746193691":"Blossom","748044252":"{value} Ulric Chests","748126555":"Wave","749141404":"Moon Guardian","749682691":"Gunslinger Champion","750450554":"Red Craft Project","751763446":"God of Wealth","752925839":"Defender","752984615":"Denim Plumber","753521148":"Earth Guard","754102085":"Prosperity","755304282":"Blighted Reaper","757281852":"Wave","757638525":"Grave Slasher","758293869":"Lavender","759293109":"Twister of Time","762358768":"Peach Blossom","763360732":"Shifu","764425193":"Imperial Black","764870575":"{value} Diamonds","766158293":"Vampire Hunter","767831061":"A Graceful Victory","768029899":"Default Pose","770477599":"Benevolent Spirit","773451577":"{value} Ulric Chest","775915738":"Bow","776255609":"Sharp Steel","778452293":"Flex","781466492":"Armored Bone Breaker","785919489":"Dark Teal Guard","786830054":"Wave","788065663":"Point","790301296":"Fire Bad","791347970":"Enzan War Strider","792487120":"{value} Diamonds","794168620":"Crimson Tonfas","795452698":"Amber Staff","795662654":"Appetizing Critter n Club","796437580":"Venomshard Dirks","796676805":"Ancient Construct","799359530":"Cherry Tick-tock","802374574":"Focus","803974673":"Random Champion","804768291":"{value} Chests","807625209":"Blood Banner","808086187":"Unholy Hunger","808339606":"Mystery Present","815964450":"{value} Gems","816257490":"Forest Green","817011310":"Salute","819085993":"Default Outfit","822495498":"{value} Chest","823239161":"Default Weapon","823798009":"Zander","824900579":"Default Pose","825115677":"Quna`s Royal Champion","825441355":"Tasty Boar n Lumber","826065237":"The smelly gift","827650056":"Mantle of the Ash Queen","828175147":"Brown Rags","828373934":"Sweet Candycorn","828786001":"Warm Brown","830123205":"Power Flows","831093530":"The Guardian Spear","831239957":"Pleased To Meet Ya","832350090":"Pale Rags","832633004":"Ancient Awakening","833481106":"Default Outfit","833561976":"All champions pack","833707813":"Golden Sapphire","833949857":"Clap","835017390":"{value} Chests","835176940":"Growlan, The Champion`s Warlion","836286979":"Deep Sea Explorer","836811715":"Golden Astral Gauge","837225887":"Wave","838246158":"Salute","838274128":"Bonfire","841765511":"Dark Guide","842211418":"Iva","842339315":"Olden Emerald","843697711":"Rusty Rifle","845899388":"Venomous Penetrator","845904999":"Fiery Yellow Guard","846336007":"Wave","847148324":"Hyacinth","847469807":"Blossom","848597725":"{value} Chests","848981581":"Thumbs Down","851427195":"Burnt Grimoire","855654795":"Shen Rao","856271838":"Ancient Serpent Conductors","858234452":"Silverdeep Court Staff","858424006":"Wave","859889709":"Stormbringer Bracers","860022274":"Iva","863234132":"The Evil Eye Bindings","864313451":"Dark Gunslinger","866601565":"Ancient Forge Conductors","870014820":"{value} Chest","870711570":"Destiny","871645157":"Silver Wind Howler","872225242":"Swift Steed","873021313":"Wonderfully smelly gift","874128173":"Radiant Avat
suckMyDict = json.loads(jsonString)

MafiaSmallDict = {
    
    'D57BBC373C35B426E93CB844B3C67C12': 'Mount Araz - Day',
    'AB201E3B9454141FE9C9352CC296AD61': 'Mount Araz - Night',
    '02EF7F035729241EF81A9BC09463DD00': 'Orman Temple - Day',
    '3482480FED2AC482AA7DA471C1990591': 'Orman Temple - Night',
    '80D7970B6650D41108D71083ECF0E49E': 'Sky Ring - Day',
    '417DE573937D74E39BF40EB6CF82670B': 'Sky Ring - Night',
    '975402A5539C6491789B36DC4D26D566': 'Blackstone Arena - Day',
    '319DDC57E70174B6C85EF137BAF34E9E': 'Blackstone Arena - Night',
    '1C67FA3426A324D39BED64501C46C1E6': 'Dragon Garden - Day',
    'FFFFE4774561141D49B46892B5CBACFA': 'Dragon Garden - Night',
    '0429CE4F9F62E4AB099C7A5BF18CC075': 'Daharin Battlegrounds - Day',
    '8B8FCB457F41C4C44A13C16551A313F7': 'Daharin Battlegrounds - NIght',
    'B7B5389657E0A42AD9E417338DF8C6F7': 'Misty Woods - Day',
    '18760A963CE9A47509682D4B43D3FF3B': 'Misty Woods - Night',
    '1CD116B3A9F9943BC98167EAAAC846D2': 'Meriko Summit - Day',
    '5CF7BC73C66BE4E8B95CE6F69035BECA': 'Meriko Summit - NIght'
     
}

# %% [markdown]
# # RESET

# %% [markdown]
# # RESET

# %%
overall_urls = []

# %% [markdown]
# # RESET

# %% [markdown]
# # RESET

# %%
current_datetime = '2019-01-06T00:00:00Z'
resetlink = 0
link = "https://api.developer.battlerite.com/shards/global/matches"

# %%
'''CHANGE THE 0 TO 1 OR HIGHER IF DF2 ALREADY EXISTS AKA YOU ALREADY HAVE DATA OR ELSE YOU WILL OVERWRITE'''

for deniz in range(0, 201600):
    
    if resetlink >= 1000:
        
        current_datetime = df2['Date'].tail(1).values[0]
        resetlink = 0
        link = "https://api.developer.battlerite.com/shards/global/matches"
    
    uselink = "{}".format(link)
    
    query = {
      "sort": "createdAt",
      "filter[createdAt-start]": "{}".format(current_datetime),
      "page[limit]": "5"}
    
    if deniz > 0:
        
        difference_runtime = end_runtime - start_runtime
        print(difference_runtime.total_seconds())

        if difference_runtime.total_seconds() < 6:
            
            if difference_runtime.total_seconds() > 0:
                
                time_to_sleep = m.ceil(6-difference_runtime.total_seconds())
                time.sleep(time_to_sleep)
    
    start_runtime = datetime.datetime.now()
    
    '''TRY THIS TO STOP SCRIPT FROM FAILING FROM CONNECTION ERROR'''
    
    try:
    
        re = requests.get(uselink, headers=header, params=query)
        re.close()
        
    except:
        
        print('ERROR')
        time.sleep(600)
        re = requests.get(uselink, headers=header, params=query)
        re.close()
    
    json_data = re.json()

    data = json_data['data']
    included = json_data['included']

    urls = []

    for i in range(len(included)):

        try: 

            urls.append(included[i]['attributes']['URL'])

        except:

            continue

    df2 = pd.DataFrame([], columns = ['Match ID', 'Region', 'map', 'Date', 'Ranking Type', 'Server Type', 'Solo Q', 'Team ID', 'Player ID', 'Season', 'mount', 'attachment', 'emote', 'outfit','Kills', 'Deaths', 'Score', 'Damage Done', 'Healing Done',
                                     'Disables Done', 'Damage Taken', 'Disables Taken', 'Healing Received', 'Energy Gain',
                                     'Energy Used', 'Time Alive', 'Abilities Used', 'Round Outcome', 'Round Number', 'Round Length','Team', 'champion', 'Champion Level',
                                     'Champion Played', 'Total Played', 'league', 'Division', 'Division Rating',
                                     'Ally 1 champion', 'Ally 1 Champion Level', 'Ally 1 Champion Played', 'Ally 1 Total Played', 'Ally 1 Score', 'Ally 1 Damage Taken', 'Ally 1 Time Alive', 'Ally 1 League',
                                     'Ally 2 champion', 'Ally 2 Champion Level', 'Ally 2 Champion Played', 'Ally 2 Total Played', 'Ally 2 Score', 'Ally 2 Damage Taken', 'Ally 2 Time Alive', 'Ally 2 League',
                                     'Enemy 1 champion', 'Enemy 1 Champion Level', 'Enemy 1 Champion Played', 'Enemy 1 Total Played', 'Enemy 1 Score', 'Enemy 1 Damage Taken', 'Enemy 1 Time Alive', 'Enemy 1 League',
                                     'Enemy 2 champion', 'Enemy 2 Champion Level', 'Enemy 2 Champion Played', 'Enemy 2 Total Played', 'Enemy 2 Score', 'Enemy 2 Damage Taken', 'Enemy 2 Time Alive', 'Enemy 2 League',
                                     'Enemy 3 champion', 'Enemy 3 Champion Level', 'Enemy 3 Champion Played', 'Enemy 3 Total Played', 'Enemy 3 Score', 'Enemy 3 Damage Taken', 'Enemy 3 Time Alive', 'Enemy 3 League'])

    df2['Kills'] = df2['Kills'].astype('int64')
    df2['Deaths'] = df2['Deaths'].astype('int64')
    df2['Score'] = df2['Score'].astype('int64')
    df2['Damage Done'] = df2['Damage Done'].astype('int64')
    df2['Healing Done'] = df2['Healing Done'].astype('int64')
    df2['Disables Done'] = df2['Disables Done'].astype('int64')
    df2['Damage Taken'] = df2['Damage Taken'].astype('int64')
    df2['Disables Taken'] = df2['Disables Taken'].astype('int64')
    df2['Healing Received'] = df2['Healing Received'].astype('int64')
    df2['Energy Gain'] = df2['Energy Gain'].astype('int64')
    df2['Energy Used'] = df2['Energy Used'].astype('int64')
    df2['Time Alive'] = df2['Time Alive'].astype('int64')
    df2['Abilities Used'] = df2['Abilities Used'].astype('int64')
    df2['Round Outcome'] = df2['Round Outcome'].astype('int64')
    df2['Round Number'] = df2['Round Number'].astype('int64')
    df2['Round Length'] = df2['Round Length'].astype('int64')
    df2['Team'] = df2['Team'].astype('int64')
    df2['champion'] = df2['champion'].astype('int64')
    df2['Ally 1 champion'] = df2['Ally 1 champion'].astype('int64')
    df2['Ally 2 champion'] = df2['Ally 2 champion'].astype('int64')
    df2['Enemy 1 champion'] = df2['Enemy 1 champion'].astype('int64')
    df2['Enemy 2 champion'] = df2['Enemy 2 champion'].astype('int64')
    df2['Enemy 3 champion'] = df2['Enemy 3 champion'].astype('int64')
    df2['league'] = df2['league'].astype('int64')
    df2['Ally 1 League'] = df2['Ally 1 League'].astype('int64')
    df2['Ally 2 League'] = df2['Ally 2 League'].astype('int64')
    df2['Enemy 1 League'] = df2['Enemy 1 League'].astype('int64')
    df2['Enemy 2 League'] = df2['Enemy 2 League'].astype('int64')
    df2['Enemy 3 League'] = df2['Enemy 3 League'].astype('int64')
    df2['mount'] = df2['mount'].astype('int64')
    df2['attachment'] = df2['attachment'].astype('int64')
    df2['emote'] = df2['emote'].astype('int64')
    df2['outfit'] = df2['outfit'].astype('int64')
    df2['Solo Q'] = df2['Solo Q'].astype('int64')

    for o in range(5):

        url = urls[o]

        if url in overall_urls:

            continue

        r2 = requests.get(url)

        rounds = r2.json()
        
        '''CHECK SERVER SHUTDOWN'''
        try:
            
            if rounds[-1]['type'] == 'Structures.ServerShutdown':
                overall_urls.append(url)
                continue
            
        except:
            
            pass
        
        player_id = []
        champion = []
        kills = []
        deaths = []
        score = []
        damage = []
        healing = []
        disables = []
        damage_taken = []
        disables_taken = []
        healing_received = []
        energy_gain = []
        energy_used = []
        time_alive = []
        abilities_used = []
        round_outcome = []
        team = []
        champion = []
        champion_level = []
        champion_played = []
        total_played = []
        ranking_type = []
        league = []
        division = []
        division_rating = []
        season = []
        mount = []
        attachment = []
        emote = []
        outfit = []
        team_id = []
        server_type = []
        match_id = []
        region = []
        br_map = []
        round_number = []
        round_length = []
        afk = False
        leaver = False
        bot_match = False

        round_end = []
        user_infos = []   

        for j in range(len(rounds)):

            if rounds[j]['type'] == 'Structures.RoundFinishedEvent':

                round_end.append(rounds[j])

            if rounds[j]['type'] == 'Structures.MatchReservedUser':

                user_infos.append(rounds[j])

        num_rounds = len(round_end)
        num_players = len(round_end[0]['dataObject']['playerStats'])
        
        if num_players == 0:
            
            num_players = len(round_end[1]['dataObject']['playerStats'])

        try:

            match_id = [rounds[0]['dataObject']['matchId']] * num_rounds * num_players

        except:

            match_id = [rounds[0]['dataObject']['matchID']] * num_rounds * num_players
                      

        for j in range(len(rounds)):

            try:

                region_insert = rounds[j]['dataObject']['region']
                map_insert = rounds[j]['dataObject']['mapID']
                break

            except:

                continue

        region = [region_insert] * num_rounds * num_players

        br_map = [map_insert] * num_rounds * num_players


        for j in range(len(data)):

            if data[j]['id'] == match_id[0]:

                date_insert = data[j]['attributes']['createdAt']     

                date = [date_insert] * num_rounds * num_players

        for r in round_end:

            players = r['dataObject']['playerStats']
            
            if len(players) != len(user_infos):
                
                bot_match = True
                break

            for player in players:

                insert_id = player['userID']
                player_id.append(insert_id)
                round_number.append(r['dataObject']['round'])
                round_length.append(r['dataObject']['roundLength'])


                for user_info in user_infos:

                    if user_info['dataObject']['accountId'] == insert_id:

                        champion.append(user_info['dataObject']['character'])
                        champion_level.append(user_info['dataObject']['characterLevel'])
                        champion_played.append(user_info['dataObject']['characterTimePlayed'])
                        total_played.append(user_info['dataObject']['totalTimePlayed'])
                        ranking_type.append(user_info['dataObject']['rankingType'])
                        league.append(user_info['dataObject']['league'])
                        division.append(user_info['dataObject']['division'])
                        division_rating.append(user_info['dataObject']['divisionRating'])
                        season.append(user_info['dataObject']['seasonId'])
                        mount.append(user_info['dataObject']['mount'])
                        attachment.append(user_info['dataObject']['attachment'])
                        emote.append(user_info['dataObject']['emote'])
                        outfit.append(user_info['dataObject']['outfit'])
                        team_id.append(user_info['dataObject']['teamId'])
                        server_type.append(user_info['dataObject']['serverType'])
                        team.append(user_info['dataObject']['team'])

                        if int(user_info['dataObject']['team']) == int(r['dataObject']['winningTeam']):

                            round_outcome.append(1)

                        else:

                            round_outcome.append(0)

                kills.append(player['kills'])
                deaths.append(player['deaths'])
                score.append(player['score'])
                damage.append(player['damageDone'])
                healing.append(player['healingDone'])
                disables.append(player['disablesDone'])
                damage_taken.append(player['damageReceived'])
                disables_taken.append(player['disablesReceived'])
                healing_received.append(player['healingReceived'])
                energy_gain.append(player['energyGained'])
                energy_used.append(player['energyUsed'])
                time_alive.append(player['timeAlive'])
                abilities_used.append(player['abilityUses'])
        
        
        if bot_match:
            
            overall_urls.append(url)
            continue
        
        
        '''ADDED TO CHECK IF THERE ARE LEAVER IN UNRANKED GAME'''
        check_num_rounds_players = 0
        
        for dewizzle in range(len(round_end)):
            
            check_num_rounds_players += len(round_end[dewizzle]['dataObject']['playerStats'])
        
        
        if check_num_rounds_players != len(region):
            
            overall_urls.append(url)
            continue
         
            
        if server_type[0] == 'PRIVATE':

            afk = False
            leaver = False
        
        else:

            for player in player_id:

                for j in range(len(rounds)):

                    try:

                        if player in rounds[j]['dataObject']['userIDs']:

                            if rounds[j]['dataObject']['rankingChangeType'] == 'AfkPenalty':

                                afk = True


                            if rounds[j]['dataObject']['rankingChangeType'] == 'LeftPenalty':

                                leaver = True


                    except:

                        continue


        if (afk or leaver):

            overall_urls.append(url)
            continue



        w = list(zip(match_id, region, br_map, date, player_id, kills, deaths, score, damage, healing, disables, damage_taken,
             disables_taken, healing_received, energy_gain, energy_used, time_alive, abilities_used,
             round_outcome, round_number, round_length, team, champion, champion_level, champion_played, total_played, ranking_type,
             league, division, division_rating, season, mount, attachment, emote, outfit, team_id, server_type))

        df = pd.DataFrame(w, columns = ['Match ID', 'Region', 'map', 'Date', 'Player ID', 'Kills', 'Deaths', 'Score', 'Damage Done', 'Healing Done',
                                        'Disables Done', 'Damage Taken', 'Disables Taken', 'Healing Received', 'Energy Gain',
                                        'Energy Used', 'Time Alive', 'Abilities Used', 'Round Outcome', 'Round Number', 'Round Length','Team', 'champion', 'Champion Level',
                                        'Champion Played', 'Total Played', 'Ranking Type', 'league', 'Division', 'Division Rating',
                                        'Season', 'mount', 'attachment', 'emote', 'outfit', 'Team ID', 'Server Type'])

        if ((df['Server Type'][0] == 'QUICK3V3') & (df['Ranking Type'][0] == 'RANKED') & (len(df['Team ID'].unique()) > 2)):

            df['Solo Q'] = 1

        else:

            df['Solo Q'] = 0


        '''THIS IS TO CHECK IF THERE WAS A LEAVER/AFK IN THE FIRST ROUND AND NOT DETECTED BY THE LEAVER/AFK CODE ABOVE'''
        if 1 not in df[['Round Number']].values:

            overall_urls.append(url)
            continue

        df['league'] = df['league'].apply(recode_league)
        
        '''TEST FOR DUPLICATE HERO IN PRIVATE MATCH'''
        
        test_dupe1 = df[(df['Team'] == 1) & df['Round Number'] == 1]
        test_dupe2 = df[(df['Team'] == 2) & df['Round Number'] == 1]
        
        if ((len(test_dupe1) != len(set(test_dupe1['champion']))) | (len(test_dupe2) != len(set(test_dupe2['champion'])))):
            
            overall_urls.append(url)
            continue

        allychampion1 = []
        allychampionlevel1 = []
        allychampionplayed1 = []
        allytotalplayed1 = []
        allyscore1 = []
        allydamagetaken1 = []
        allytimealive1 = []
        allyleague1 = []

        allychampion2 = []
        allychampionlevel2 = []
        allychampionplayed2 = []
        allytotalplayed2 = []
        allyscore2 = []
        allydamagetaken2 = []
        allytimealive2 = []
        allyleague2 = []

        enemychampion1 = []
        enemychampionlevel1 = []
        enemychampionplayed1 = []
        enemytotalplayed1 = []
        enemyscore1 = []
        enemydamagetaken1 = []
        enemytimealive1 = []
        enemyleague1 = []

        enemychampion2 = []
        enemychampionlevel2 = []
        enemychampionplayed2 = []
        enemytotalplayed2 = []
        enemyscore2 = []
        enemydamagetaken2 = []
        enemytimealive2 = []
        enemyleague2 = []

        enemychampion3 = []
        enemychampionlevel3 = []
        enemychampionplayed3 = []
        enemytotalplayed3 = []
        enemyscore3 = []
        enemydamagetaken3 = []
        enemytimealive3 = []
        enemyleague3 = []


        for i in range(len(df)):
            selfchampion = df['champion'][i]
            br_round = df['Round Number'][i]
            br_team = df['Team'][i]

            Df2 = df[(df['Team'] == br_team) & (df['Round Number'] == br_round) & (df['champion'] != selfchampion)]
            Df2.reset_index(inplace = True, drop = True)
            Df3 = df[(df['Team'] != br_team) & (df['Round Number'] == br_round)]
            Df3.reset_index(inplace = True, drop = True)
            
            if len(players)/2 >= 2:
            
                allyscore1.append(Df2['Score'][0])
                allydamagetaken1.append(Df2['Damage Taken'][0])
                allytimealive1.append(Df2['Time Alive'][0])
                allyleague1.append(Df2['league'][0])
                allychampion1.append(Df2['champion'][0])
                allychampionlevel1.append(Df2['Champion Level'][0])
                allychampionplayed1.append(Df2['Champion Played'][0])
                allytotalplayed1.append(Df2['Total Played'][0])
                
            else:
                
                allyscore1.append(0)
                allydamagetaken1.append(0)
                allytimealive1.append(0)
                allyleague1.append(0)
                allychampion1.append(0)
                allychampionlevel1.append(0)
                allychampionplayed1.append(0)
                allytotalplayed1.append(0)


            if len(players)/2 == 3:

                allyscore2.append(Df2['Score'][1])
                allydamagetaken2.append(Df2['Damage Taken'][1])
                allytimealive2.append(Df2['Time Alive'][1])
                allyleague2.append(Df2['league'][1])
                allychampion2.append(Df2['champion'][1])
                allychampionlevel2.append(Df2['Champion Level'][1])
                allychampionplayed2.append(Df2['Champion Played'][1])
                allytotalplayed2.append(Df2['Total Played'][1])

            else:

                allyscore2.append(0)
                allydamagetaken2.append(0)
                allytimealive2.append(0)
                allyleague2.append(0)
                allychampion2.append(0)
                allychampionlevel2.append(0)
                allychampionplayed2.append(0)
                allytotalplayed2.append(0)

            enemychampion1.append(Df3['champion'][0])
            enemychampionlevel1.append(Df3['Champion Level'][0])
            enemychampionplayed1.append(Df3['Champion Played'][0])
            enemytotalplayed1.append(Df3['Total Played'][0])
            enemyscore1.append(Df3['Score'][0])
            enemydamagetaken1.append(Df3['Damage Taken'][0])
            enemytimealive1.append(Df3['Time Alive'][0])
            enemyleague1.append(Df3['league'][0])

            if len(players)/2 >= 2:
            
                enemychampion2.append(Df3['champion'][1])
                enemychampionlevel2.append(Df3['Champion Level'][1])
                enemychampionplayed2.append(Df3['Champion Played'][1])
                enemytotalplayed2.append(Df3['Total Played'][1])
                enemyscore2.append(Df3['Score'][1])
                enemydamagetaken2.append(Df3['Damage Taken'][1])
                enemytimealive2.append(Df3['Time Alive'][1])
                enemyleague2.append(Df3['league'][1])
                
            else:
                
                enemychampion2.append(0)
                enemychampionlevel2.append(0)
                enemychampionplayed2.append(0)
                enemytotalplayed2.append(0)
                enemyscore2.append(0)
                enemydamagetaken2.append(0)
                enemytimealive2.append(0)
                enemyleague2.append(0)
                

            if len(players)/2 == 3:

                enemychampion3.append(Df3['champion'][2])
                enemychampionlevel3.append(Df3['Champion Level'][2])
                enemychampionplayed3.append(Df3['Champion Played'][2])
                enemytotalplayed3.append(Df3['Total Played'][2])
                enemyscore3.append(Df3['Score'][2])
                enemydamagetaken3.append(Df3['Damage Taken'][2])
                enemytimealive3.append(Df3['Time Alive'][2])
                enemyleague3.append(Df3['league'][2])

            else:

                enemychampion3.append(0)
                enemychampionlevel3.append(0)
                enemychampionplayed3.append(0)
                enemytotalplayed3.append(0)
                enemyscore3.append(0)
                enemydamagetaken3.append(0)
                enemytimealive3.append(0)
                enemyleague3.append(0)

        df['Ally 1 champion'] = allychampion1
        df['Ally 1 Champion Level'] = allychampionlevel1
        df['Ally 1 Champion Played'] = allychampionplayed1
        df['Ally 1 Total Played'] = allytotalplayed1
        df['Ally 1 Score'] = allyscore1
        df['Ally 1 Damage Taken'] = allydamagetaken1
        df['Ally 1 Time Alive'] = allytimealive1
        df['Ally 1 League'] = allyleague1

        df['Ally 2 champion'] = allychampion2
        df['Ally 2 Champion Level'] = allychampionlevel2
        df['Ally 2 Champion Played'] = allychampionplayed2
        df['Ally 2 Total Played'] = allytotalplayed2
        df['Ally 2 Score'] = allyscore2
        df['Ally 2 Damage Taken'] = allydamagetaken2
        df['Ally 2 Time Alive'] = allytimealive2
        df['Ally 2 League'] = allyleague2

        df['Enemy 1 champion'] = enemychampion1
        df['Enemy 1 Champion Level'] = enemychampionlevel1
        df['Enemy 1 Champion Played'] = enemychampionplayed1
        df['Enemy 1 Total Played'] = enemytotalplayed1
        df['Enemy 1 Score'] = enemyscore1
        df['Enemy 1 Damage Taken'] = enemydamagetaken1
        df['Enemy 1 Time Alive'] = enemytimealive1
        df['Enemy 1 League'] = enemyleague1

        df['Enemy 2 champion'] = enemychampion2
        df['Enemy 2 Champion Level'] = enemychampionlevel2
        df['Enemy 2 Champion Played'] = enemychampionplayed2
        df['Enemy 2 Total Played'] = enemytotalplayed2
        df['Enemy 2 Score'] = enemyscore2
        df['Enemy 2 Damage Taken'] = enemydamagetaken2
        df['Enemy 2 Time Alive'] = enemytimealive2
        df['Enemy 2 League'] = enemyleague2

        df['Enemy 3 champion'] = enemychampion3
        df['Enemy 3 Champion Level'] = enemychampionlevel3
        df['Enemy 3 Champion Played'] = enemychampionplayed3
        df['Enemy 3 Total Played'] = enemytotalplayed3
        df['Enemy 3 Score'] = enemyscore3
        df['Enemy 3 Damage Taken'] = enemydamagetaken3
        df['Enemy 3 Time Alive'] = enemytimealive3
        df['Enemy 3 League'] = enemyleague3



        df = df[['Match ID', 'Region', 'map', 'Date', 'Ranking Type', 'Server Type', 'Solo Q', 'Team ID', 'Player ID', 'Season', 'mount', 'attachment', 'emote', 'outfit','Kills', 'Deaths', 'Score', 'Damage Done', 'Healing Done',
                                     'Disables Done', 'Damage Taken', 'Disables Taken', 'Healing Received', 'Energy Gain',
                                     'Energy Used', 'Time Alive', 'Abilities Used', 'Round Outcome', 'Round Number', 'Round Length','Team', 'champion', 'Champion Level',
                                     'Champion Played', 'Total Played', 'league', 'Division', 'Division Rating',
                                     'Ally 1 champion', 'Ally 1 Champion Level', 'Ally 1 Champion Played', 'Ally 1 Total Played', 'Ally 1 Score', 'Ally 1 Damage Taken', 'Ally 1 Time Alive', 'Ally 1 League',
                                     'Ally 2 champion', 'Ally 2 Champion Level', 'Ally 2 Champion Played', 'Ally 2 Total Played', 'Ally 2 Score', 'Ally 2 Damage Taken', 'Ally 2 Time Alive', 'Ally 2 League',
                                     'Enemy 1 champion', 'Enemy 1 Champion Level', 'Enemy 1 Champion Played', 'Enemy 1 Total Played', 'Enemy 1 Score', 'Enemy 1 Damage Taken', 'Enemy 1 Time Alive', 'Enemy 1 League',
                                     'Enemy 2 champion', 'Enemy 2 Champion Level', 'Enemy 2 Champion Played', 'Enemy 2 Total Played', 'Enemy 2 Score', 'Enemy 2 Damage Taken', 'Enemy 2 Time Alive', 'Enemy 2 League',
                                     'Enemy 3 champion', 'Enemy 3 Champion Level', 'Enemy 3 Champion Played', 'Enemy 3 Total Played', 'Enemy 3 Score', 'Enemy 3 Damage Taken', 'Enemy 3 Time Alive', 'Enemy 3 League']]
  
        df2 = pd.concat([df2, df], axis = 0)

        
        df2.reset_index(inplace = True, drop = True)
        overall_urls.append(url)
        print(df2['Date'].tail(1).values[0])


    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'champion', value_name = 'Champion')
    stuff['champion'] = stuff['champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'champion', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'emote', value_name = 'Emote')
    stuff['emote'] = stuff['emote'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'emote', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'mount', value_name = 'Mount')
    stuff['mount'] = stuff['mount'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'mount', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'outfit', value_name = 'Outfit')
    stuff['outfit'] = stuff['outfit'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'outfit', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'attachment', value_name = 'Attachment')
    stuff['attachment'] = stuff['attachment'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'attachment', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'Ally 1 champion', value_name = 'Ally 1 Champion')
    stuff['Ally 1 champion'] = stuff['Ally 1 champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'Ally 1 champion', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'Ally 2 champion', value_name = 'Ally 2 Champion')
    stuff['Ally 2 champion'] = stuff['Ally 2 champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'Ally 2 champion', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'Enemy 1 champion', value_name = 'Enemy 1 Champion')
    stuff['Enemy 1 champion'] = stuff['Enemy 1 champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'Enemy 1 champion', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'Enemy 2 champion', value_name = 'Enemy 2 Champion')
    stuff['Enemy 2 champion'] = stuff['Enemy 2 champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'Enemy 2 champion', how = 'inner')

    stuff = pd.DataFrame(suckMyDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'Enemy 3 champion', value_name = 'Enemy 3 Champion')
    stuff['Enemy 3 champion'] = stuff['Enemy 3 champion'].astype('int64')

    df2 = pd.merge(left = df2, right = stuff, on = 'Enemy 3 champion', how = 'inner')

    stuff = pd.DataFrame(MafiaSmallDict, index=[0])
    stuff = pd.melt(frame = stuff, var_name = 'map', value_name = 'Map')

    df2 = pd.merge(left = df2, right = stuff, on = 'map', how = 'inner')

    df2 = df2[['Match ID', 'Region', 'Map', 'Date', 'Ranking Type', 'Server Type', 'Solo Q', 'Team ID', 'Player ID', 'Season', 'Mount', 'Attachment', 'Emote', 'Outfit','Kills', 'Deaths', 'Score', 'Damage Done', 'Healing Done',
                                     'Disables Done', 'Damage Taken', 'Disables Taken', 'Healing Received', 'Energy Gain',
                                     'Energy Used', 'Time Alive', 'Abilities Used', 'Round Outcome', 'Round Number', 'Round Length', 'Champion', 'Champion Level',
                                     'Champion Played', 'Total Played', 'league', 'Division', 'Division Rating',
                                     'Ally 1 Champion', 'Ally 1 Champion Level', 'Ally 1 Champion Played', 'Ally 1 Total Played', 'Ally 1 Score', 'Ally 1 Damage Taken', 'Ally 1 Time Alive', 'Ally 1 League',
                                     'Ally 2 Champion', 'Ally 2 Champion Level', 'Ally 2 Champion Played', 'Ally 2 Total Played', 'Ally 2 Score', 'Ally 2 Damage Taken', 'Ally 2 Time Alive', 'Ally 2 League',
                                     'Enemy 1 Champion', 'Enemy 1 Champion Level', 'Enemy 1 Champion Played', 'Enemy 1 Total Played', 'Enemy 1 Score', 'Enemy 1 Damage Taken', 'Enemy 1 Time Alive', 'Enemy 1 League',
                                     'Enemy 2 Champion', 'Enemy 2 Champion Level', 'Enemy 2 Champion Played', 'Enemy 2 Total Played', 'Enemy 2 Score', 'Enemy 2 Damage Taken', 'Enemy 2 Time Alive', 'Enemy 2 League',
                                     'Enemy 3 Champion', 'Enemy 3 Champion Level', 'Enemy 3 Champion Played', 'Enemy 3 Total Played', 'Enemy 3 Score', 'Enemy 3 Damage Taken', 'Enemy 3 Time Alive', 'Enemy 3 League']]

    df2 = df2.rename(columns = {'league':'League'}) 
          
    if deniz == 0:
        
        DF2 = df2.copy()
        end_runtime = datetime.datetime.now()
        resetlink += 1
        link = json_data['links']['next']
        
    else:
        
        DF2 = pd.concat([DF2, df2], axis = 0)
        end_runtime = datetime.datetime.now()
        resetlink +=1
        link = json_data['links']['next']
        print(len(DF2))
        print(len(overall_urls))

# %%
DF2.to_csv('Battlerite_data.csv')
